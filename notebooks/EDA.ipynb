# %%
import yfinance as yf
import pandas as pd

# Download and reset index so Date is a column
df = yf.download('AAPL', start='2020-01-01', end='2024-01-01')
df.reset_index(inplace=True)  # <- This is important!
df.to_csv('../data/raw/AAPL.csv', index=False)  # Save with Date as column
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date      Close       High        Low       Open     Volume
# Ticker                  AAPL       AAPL       AAPL       AAPL       AAPL
# 0      2020-01-02  72.620834  72.681281  71.373211  71.627084  135480400
# 1      2020-01-03  71.914833  72.676462  71.689973  71.847133  146322800
# 2      2020-01-06  72.487846  72.526533  70.783248  71.034709  118387200
# 3      2020-01-07  72.146950  72.753831  71.926922  72.497537  108872000
# 4      2020-01-08  73.307503  73.609737  71.849525  71.849525  132079200

# %%
# Plot closing price
df['Close'].plot(title='AAPL Closing Price')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.grid(True)
plt.show()

# %%
# Check for missing data
df.isnull().sum()
# Out:
# Price   Ticker
# Date              0
# Close   AAPL      0
# High    AAPL      0
# Low     AAPL      0
# Open    AAPL      0
# Volume  AAPL      0
# dtype: int64
